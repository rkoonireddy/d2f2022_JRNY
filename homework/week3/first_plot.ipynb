# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('D:\Studies\Sem 2\Digital tools for finance\d2f2022_JRNY\homework\week3\coding-environment-exercise.csv')
data.head()
x=plt.plot(data['date'],data['value'])
print(x)
